# %% [markdown]
# <a href="https://colab.research.google.com/github/sandhya-8368/Global-Terrorism-Analysis/blob/main/Copy_of_Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %% [markdown]
# # In our overview of terrorism, we tried to understand how the number of terrorists acts varies around the world and how it has changed over time.To do this, we needed a clear and massive amount of terrorists attack that happened over time.What we are doing here is we are understanding the data set given to us and analysing eveything related to terrorists attack and giving insights about our observation through this exploratory data analysis.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("/content/drive/MyDrive/Copy of Global Terrorism Data.csv",encoding=("ISO-8859-1"))
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# df = df.replace(r'?', np.NaN)                                                   
# df = df.replace(r'n.a', np.NaN)                                              

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.columns.to_list()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
#  'gname3',
#  'gsubname3',
#  'motive',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'individual',
#  'nperps',
#  'nperpcap',
#  'claimed',
#  'claimmode',
#  'claimmode_txt',
#  'claim2',
#  'claimmode2',
#  'claimmode2_txt',
#  'claim3',
#  'claimmode3',
#  'claimmode3_txt',
#  'compclaim',
#  'weaptype1',
#  'weaptype1_txt',
#  'weapsubtype1',
#  'weapsubtype1_txt',
#  'weaptype2',
#  'weaptype2_txt',
#  'weapsubtype2',
#  'weapsubtype2_txt',
#  'weaptype3',
#  'weaptype3_txt',
#  'weapsubtype3',
#  'weapsubtype3_txt',
#  'weaptype4',
#  'weaptype4_txt',
#  'weapsubtype4',
#  'weapsubtype4_txt',
#  'weapdetail',
#  'nkill',
#  'nkillus',
#  'nkillter',
#  'nwound',
#  'nwoundus',
#  'nwoundte',
#  'property',
#  'propextent',
#  'propextent_txt',
#  'propvalue',
#  'propcomment',
#  'ishostkid',
#  'nhostkid',
#  'nhostkidus',
#  'nhours',
#  'ndays',
#  'divert',
#  'kidhijcountry',
#  'ransom',
#  'ransomamt',
#  'ransomamtus',
#  'ransompaid',
#  'ransompaidus',
#  'ransomnote',
#  'hostkidoutcome',
#  'hostkidoutcome_txt',
#  'nreleased',
#  'addnotes',
#  'scite1',
#  'scite2',
#  'scite3',
#  'dbsource',
#  'INT_LOG',
#  'INT_IDEO',
#  'INT_MISC',
#  'INT_ANY',
#  'related']

# %%
attack=df[['iyear','imonth','iday','country_txt','region_txt','city','success','claimed','suicide','attacktype1_txt','targtype1_txt','extended','targsubtype1_txt','gname','motive','weaptype1_txt','nkill','nwound','property','nhostkid','vicinity','weapsubtype1_txt']]
attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   imonth            181691 non-null  int64
#  2   iday              181691 non-null  int64
#  3   country_txt       181691 non-null  object
#  4   region_txt        181691 non-null  object
#  5   city              181257 non-null  object
#  6   success           181691 non-null  int64
#  7   claimed           115571 non-null  float64
#  8   suicide           181691 non-null  int64
#  9   attacktype1_txt   181691 non-null  object
#  10  targtype1_txt     181691 non-null  object
#  11  extended          181691 non-null  int64
#  12  targsubtype1_txt  171318 non-null  object
#  13  gname             181691 non-null  object
#  14  motive            50561 non-null   object
#  15  weaptype1_txt     181691 non-null  object
#  16  nkill             171378 non-null  float64
#  17  nwound            165380 non-null  float64
#  18  property          181691 non-null  int64
#  19  nhostkid          13572 non-null   float64
#  20  vicinity          181691 non-null  int64
#  21  weapsubtype1_txt  160923 non-null  object
# dtypes: float64(4), int64(8), object(10)
# memory usage: 30.5+ MB

# %%
attack.shape
# Out:
# (181691, 22)

# %%
attack.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#             city  success  claimed  suicide                 attacktype1_txt  \
# 0  Santo Domingo        1      NaN        0                   Assassination
# 1    Mexico city        1      NaN        0     Hostage Taking (Kidnapping)
# 2        Unknown        1      NaN        0                   Assassination
# 3         Athens        1      NaN        0               Bombing/Explosion
# 4        Fukouka        1      NaN        0  Facility/Infrastructure Attack
#
#    ...                                   targsubtype1_txt  \
# 0  ...                                     Named Civilian
# 1  ...  Diplomatic Personnel (outside of embassy, cons...
# 2  ...                    Radio Journalist/Staff/Facility
# 3  ...                                  Embassy/Consulate
# 4  ...                                  Embassy/Consulate
#
#                                 gname motive weaptype1_txt nkill nwound  \
# 0                              MANO-D    NaN       Unknown   1.0    0.0
# 1  23rd of September Communist League    NaN       Unknown   0.0    0.0
# 2                             Unknown    NaN       Unknown   1.0    0.0
# 3                             Unknown    NaN    Explosives   NaN    NaN
# 4                             Unknown    NaN    Incendiary   NaN    NaN
#
#    property  nhostkid  vicinity        weapsubtype1_txt
# 0         0       NaN         0                     NaN
# 1         0       1.0         0                     NaN
# 2         0       NaN         0                     NaN
# 3         1       NaN         0  Unknown Explosive Type
# 4         1       NaN         0                     NaN
#
# [5 rows x 22 columns]

# %%
attack.isna().sum()
# Out:
# iyear                    0
# imonth                   0
# iday                     0
# country_txt              0
# region_txt               0
# city                   434
# success                  0
# claimed              66120
# suicide                  0
# attacktype1_txt          0
# targtype1_txt            0
# extended                 0
# targsubtype1_txt     10373
# gname                    0
# motive              131130
# weaptype1_txt            0
# nkill                10313
# nwound               16311
# property                 0
# nhostkid            168119
# vicinity                 0
# weapsubtype1_txt     20768
# dtype: int64

# %%
attack[['city','targsubtype1_txt','motive','nkill','nwound','nhostkid','claimed','weapsubtype1_txt']]=attack[['city','targsubtype1_txt','motive','nkill','nwound','nhostkid','claimed','weapsubtype1_txt']].fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
attack.isnull().sum()
# Out:
# iyear               0
# imonth              0
# iday                0
# country_txt         0
# region_txt          0
# city                0
# success             0
# claimed             0
# suicide             0
# attacktype1_txt     0
# targtype1_txt       0
# extended            0
# targsubtype1_txt    0
# gname               0
# motive              0
# weaptype1_txt       0
# nkill               0
# nwound              0
# property            0
# nhostkid            0
# vicinity            0
# weapsubtype1_txt    0
# dtype: int64

# %% [markdown]
# ## 1.Correlation Analysis

# %%
plt.figure(figsize=(15,10))
sns.heatmap(np.round(attack.corr(),2),annot=True,vmin=0,vmax=10,cmap="gist_heat")

# %% [markdown]
# # **1.which year has the most terrorist attack?**

# %%
Attacks=attack["iyear"].value_counts().sort_index().to_frame().reset_index().rename(columns={"index":"year","year":"Attack"}).set_index("year")
Attacks.head()
# Out:
#       iyear
# year
# 1970    651
# 1971    471
# 1972    568
# 1973    473
# 1974    581

# %%
# Attacks.plot(kind="bar",color="red",figsize=(15,6))
# plt.title("Attack per wise")
# # #plt.xlabel("years")
# plt.ylabel("number of attacks")
# plt.show()
plt.figure(figsize=(15,5))
sns.countplot(x=attack.iyear)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## According to this graph we saw that year 2014 has highest number of attacks and the year 1971 has the lowest number of attacks

# %% [markdown]
# # **Month wise Analysis**

# %%
monthwise_attacks=attack.drop(attack[(attack["imonth"]==0)|(attack["iday"]==0)].index)
monthwise_attacks
# Out:
#         iyear  imonth  iday         country_txt                   region_txt  \
# 0        1970       7     2  Dominican Republic  Central America & Caribbean
# 5        1970       1     1       United States                North America
# 6        1970       1     2             Uruguay                South America
# 7        1970       1     2       United States                North America
# 8        1970       1     2       United States                North America
# ...       ...     ...   ...                 ...                          ...
# 181686   2017      12    31             Somalia           Sub-Saharan Africa
# 181687   2017      12    31               Syria   Middle East & North Africa
# 181688   2017      12    31         Philippines               Southeast Asia
# 181689   2017      12    31               India                   South Asia
# 181690   2017      12    31         Philippines               Southeast Asia
#
#                  city  success  claimed  suicide  \
# 0       Santo Domingo        1      0.0        0
# 5               Cairo        1      0.0        0
# 6          Montevideo        0      0.0        0
# 7             Oakland        1      0.0        0
# 8             Madison        1      1.0        0
# ...               ...      ...      ...      ...
# 181686  Ceelka Geelow        1      1.0        0
# 181687         Jableh        1      0.0        0
# 181688       Kubentog        1      0.0        0
# 181689         Imphal        0      0.0        0
# 181690  Cotabato City        0      0.0        0
#
#                        attacktype1_txt  ...  \
# 0                        Assassination  ...
# 5                        Armed Assault  ...
# 6                        Assassination  ...
# 7                    Bombing/Explosion  ...
# 8       Facility/Infrastructure Attack  ...
# ...                                ...  ...
# 181686                   Armed Assault  ...
# 181687               Bombing/Explosion  ...
# 181688  Facility/Infrastructure Attack  ...
# 181689               Bombing/Explosion  ...
# 181690               Bombing/Explosion  ...
#
#                                        targsubtype1_txt  \
# 0                                        Named Civilian
# 5       Police Building (headquarters, station, school)
# 6                       Police Security Forces/Officers
# 7                                           Electricity
# 8                   Military Recruiting Station/Academy
# ...                                                 ...
# 181686                              Military Checkpoint
# 181687    Military Barracks/Base/Headquarters/Checkpost
# 181688                        House/Apartment/Residence
# 181689              Government Building/Facility/Office
# 181690                                                0
#
#                                              gname  \
# 0                                           MANO-D
# 5                               Black Nationalists
# 6                              Tupamaros (Uruguay)
# 7                                          Unknown
# 8                                  New Year's Gang
# ...                                            ...
# 181686                                  Al-Shabaab
# 181687                           Muslim extremists
# 181688  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689                                     Unknown
# 181690                                     Unknown
#
#                                                 motive weaptype1_txt nkill  \
# 0                                                    0       Unknown   1.0
# 5       To protest the Cairo Illinois Police Deparment      Firearms   0.0
# 6                                                    0      Firearms   0.0
# 7                                                    0    Explosives   0.0
# 8          To protest the War in Vietnam and the draft    Incendiary   0.0
# ...                                                ...           ...   ...
# 181686                                               0      Firearms   1.0
# 181687                                               0    Explosives   2.0
# 181688                                               0    Incendiary   0.0
# 181689                                               0    Explosives   0.0
# 181690                                               0    Explosives   0.0
#
#        nwound  property  nhostkid  vicinity  \
# 0         0.0         0       0.0         0
# 5         0.0         1       0.0         0
# 6         0.0         0       0.0         0
# 7         0.0         1       0.0         0
# 8         0.0         1       0.0         0
# ...       ...       ...       ...       ...
# 181686    2.0        -9       0.0         0
# 181687    7.0         1       0.0         1
# 181688    0.0         1       0.0         0
# 181689    0.0        -9       0.0         0
# 181690    0.0         0       0.0         0
#
#                                  weapsubtype1_txt
# 0                                               0
# 5                                Unknown Gun Type
# 6               Automatic or Semi-Automatic Rifle
# 7                          Unknown Explosive Type
# 8                    Molotov Cocktail/Petrol Bomb
# ...                                           ...
# 181686                           Unknown Gun Type
# 181687  Projectile (rockets, mortars, RPGs, etc.)
# 181688                                 Arson/Fire
# 181689                                    Grenade
# 181690                     Unknown Explosive Type
#
# [180800 rows x 22 columns]

# %%
monthwise=pd.DataFrame(monthwise_attacks,columns=["imonth"])
monthwise=monthwise.groupby(["imonth"])["imonth"].count().reset_index(name="month_count")
monthwise
# Out:
#     imonth  month_count
# 0        1        14842
# 1        2        13817
# 2        3        15195
# 3        4        15072
# 4        5        16809
# 5        6        15295
# 6        7        16217
# 7        8        15733
# 8        9        14099
# 9       10        15474
# 10      11        14822
# 11      12        13425

# %%
sns.barplot(x="imonth",y="month_count",data=monthwise)
sns.set(rc={'figure.figsize':(10,5)})
plt.xticks(rotation=90)
plt.ylabel=("number of attacks")

# %% [markdown]
# # **2.Which region has the most terrorist attack?**

# %%
reg=pd.crosstab(attack.iyear,attack.region_txt)

# %%
reg.plot(kind="area",stacked=False,alpha=0.5,figsize=(20,10))
plt.title("Region wise attacks")
plt.xlabel=("years")
#plt.ylabel("Numbers of attacks",fontsize=20)
plt.show()

# %% [markdown]
# This graph shows which region has highest and lowest attacks.

# %% [markdown]
# # **3. Region wise successful and unsuccessfull attacks.**

# %%
success_rate = attack.groupby(['region_txt','success'])['region_txt'].count().unstack()
success_rate
# Out:
# success                         0      1
# region_txt
# Australasia & Oceania          42    240
# Central America & Caribbean   365   9979
# Central Asia                   58    505
# East Asia                     122    680
# Eastern Europe                707   4437
# Middle East & North Africa   6155  44319
# North America                 562   2894
# South America                1358  17620
# South Asia                   5605  39369
# Southeast Asia               1334  11151
# Sub-Saharan Africa           1273  16277
# Western Europe               2478  14161

# %%
plt.rcParams['figure.figsize'] = (50, 15)
success_rate.plot()
plt.title('Number of successfull attack')
#plt.ylabel('Number of attack')
#plt.xlabel('region')
# Out:
# Text(0.5, 1.0, 'Number of successfull attack')

# %% [markdown]
# # **4.which country has been attacked most by the terrorist?**

# %%
no_of_attacked_country=attack.country_txt.value_counts()[:10]
no_of_attacked_country.head()
# Out:
# Iraq           24636
# Pakistan       14368
# Afghanistan    12731
# India          11960
# Colombia        8306
# Name: country_txt, dtype: int64

# %%
no_of_attacked_country.plot(kind='bar',figsize=(40,20))
plt.title("country wise attacks")
#plt.xlabel=("countries",fontsize=10)
plt.xticks(fontsize=30)
#plt.ylabel("number of attacks")
plt.show()

# %%
city=attack.loc[attack['country_txt']=='Iraq'].count()

# %% [markdown]
# # **5.Country wise successful and unsuccessfull attacks?**

# %%
success_rate_country = attack.groupby(['country_txt','success'])['country_txt'].count().unstack()
a=success_rate_country[:10]
a
# Out:
# success                   0        1
# country_txt
# Afghanistan          1590.0  11141.0
# Albania                16.0     64.0
# Algeria               182.0   2561.0
# Andorra                 NaN      1.0
# Angola                 13.0    486.0
# Antigua and Barbuda     NaN      1.0
# Argentina             101.0    714.0
# Armenia                 4.0     20.0
# Australia              17.0     97.0
# Austria                27.0     88.0

# %%
plt.rcParams['figure.figsize'] = (40, 15)
a.plot()
plt.title('Number of successfull attack per country')
plt.ylabel('Number of attack')
#plt.xlabel('region')
# Out:
# Text(0, 0.5, 'Number of attack')

# %% [markdown]
# # **6.which city has been attacked most by the terrorist?**

# %%
City=attack["city"].value_counts()[:10]
City
# Out:
# Unknown         9775
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Name: city, dtype: int64

# %%
my_colors = ['red', 'green', 'blue', 'black']
City.plot(kind='bar',figsize=(35,10),color=my_colors)
plt.title('Most attacked city')
#plt.ylabel('Total number ')
#plt.xlabel('City name')
plt.show()

# %% [markdown]
# # **7.City wise successful and unsuccessfull attacks?**

# %%
success_rate_city = attack.groupby(['city','success'])['city'].count().unstack()[:10]
success_rate_city
# Out:
# success                        0      1
# city
# 0                           28.0  406.0
# 62 miles South of Dushanbe   NaN    1.0
# A Coruna district            4.0   16.0
# A'arbaniyeh                  NaN    1.0
# ANkara                       NaN    1.0
# Aab Kamra                    NaN    1.0
# Aabde                        NaN    1.0
# Aabdeh                       NaN    1.0
# Aabgarmak                    NaN    1.0
# Aachen                       NaN    4.0

# %%
plt.rcParams['figure.figsize'] = (40, 15)
success_rate_city .plot()
plt.title('Number of successfull attack per city')
plt.ylabel('Number of attack')
#plt.xlabel('region')
# Out:
# Text(0, 0.5, 'Number of attack')

# %% [markdown]
# # **8.Which are the 10 top most dangerous Gang?**

# %%
terrific_gang=attack.gname.value_counts()[:10].reset_index().rename(columns={'index':'gang_name','gname':'count'})
terrific_gang
# Out:
#                                           gang_name  count
# 0                                           Unknown  82782
# 1                                           Taliban   7478
# 2       Islamic State of Iraq and the Levant (ISIL)   5613
# 3                                 Shining Path (SL)   4555
# 4  Farabundo Marti National Liberation Front (FMLN)   3351
# 5                                        Al-Shabaab   3288
# 6                           New People's Army (NPA)   2772
# 7                       Irish Republican Army (IRA)   2671
# 8     Revolutionary Armed Forces of Colombia (FARC)   2487
# 9                                        Boko Haram   2418

# %%
gang_name=terrific_gang.loc[:,'gang_name']
count=terrific_gang.loc[:,'count']

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(count, labels = gang_name,autopct='%.0f%%')
plt.show()

# %% [markdown]
# # **9.What are the success ratio of extended,success,suicide,claimed,property,vicinity?**

# %%
plt.figure(figsize=(20,20))
plt.subplot(4,2,1)
sns.countplot(x=attack.extended)
plt.subplot(4,2,3)
sns.countplot(x=attack.success)
plt.subplot(4,2,5)
sns.countplot(x=attack.suicide)
plt.subplot(4,2,2)
sns.countplot(x=attack.claimed)
plt.subplot(4,2,4)
sns.countplot(x=attack.property)
plt.subplot(4,2,6)
sns.countplot(x=attack.vicinity)
plt.show()

# %% [markdown]
# # **9.which mode of attack used by terrorists?**

# %%
plt.figure(figsize=(35,15))
sns.countplot(x=attack. attacktype1_txt,palette='flare')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **10. Which weapons and subweapons is used by terrorist?**

# %%
Weapon=attack.weaptype1_txt.value_counts()
Weapon
# Out:
# Explosives                                                                     92426
# Firearms                                                                       58524
# Unknown                                                                        15157
# Incendiary                                                                     11135
# Melee                                                                           3655
# Chemical                                                                         321
# Sabotage Equipment                                                               141
# Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)      136
# Other                                                                            114
# Biological                                                                        35
# Fake Weapons                                                                      33
# Radiological                                                                      14
# Name: weaptype1_txt, dtype: int64

# %%
plt.figure(figsize=(35,15))
sns.countplot(x=attack.weaptype1_txt)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Weapon subtype used by terrorist**

# %%
plt.figure(figsize=(50,20))
sns.countplot(x=attack.weapsubtype1_txt,palette="icefire")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **11.Terrorist target which sector and the sub sector the most?**

# %% [markdown]
# # **Sector**

# %%
target_type=attack.targtype1_txt.value_counts()
target_type
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: targtype1_txt, dtype: int64

# %%
plt.figure(figsize=(50,10))
sns.countplot(x=attack.targtype1_txt)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Subsector**

# %%
target_subtype=attack.targsubtype1_txt.value_counts()
target_subtype
# Out:
# Unnamed Civilian/Unspecified                               11596
# Police Security Forces/Officers                            11178
# 0                                                          10373
# Military Unit/Patrol/Convoy                                 8277
# Military Personnel (soldiers, troops, officers, forces)     7963
#                                                            ...
# Multiple Telecommunication Targets                            31
# Fire Fighter/Truck                                            27
# Oil Tanker                                                    19
# Personnel                                                     19
# Internet Infrastructure                                       12
# Name: targsubtype1_txt, Length: 113, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (30, 10)
target_subtype.plot(kind='bar')

plt.title('Types of target')
plt.ylabel('Total number ')
#plt.xlabel('target_subtypes')
# Out:
# Text(0, 0.5, 'Total number ')

# %% [markdown]
# # **Comparison between target type and target subtype**

# %%
sns.jointplot(x=target_type, y=target_subtype, data=attack)

# %% [markdown]
# # **12.which are the top Most Terrorists gangs operating in countries?**

# %%
no_of_attack_country=attack[["gname","country_txt"]].value_counts().drop("Unknown")
no_of_attack_country
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# gname                                             country_txt
# Taliban                                           Afghanistan    7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq           4797
# Shining Path (SL)                                 Peru           4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador    3330
# Al-Shabaab                                        Somalia        2867
#                                                                  ...
# Anti-Iran Government Exiles                       Germany           1
# Left-Wing Terrorists                              Bolivia           1
#                                                   Brazil            1
#                                                   Colombia          1
# leftist guerrillas-Bolivarian militia             Colombia          1
# Length: 5171, dtype: int64

# %%
no_of_attack_country.head(10).plot(kind="bar",figsize=(15,6),color='red')
plt.title("countries with most attacks by a group")
#plt.xlabel("(terrorist group,country)")
plt.ylabel("number of attacks")
plt.show()

# %% [markdown]
# # **13.Gangs operating in different regions?**

# %%
gang_name = attack.groupby(['region_txt','gname'])['gname'].count().unstack()
gang_name.fillna(value = 0,inplace = True)

# %%
attack.groupby(['region_txt','gname'])['region_txt'].count()
# Out:
# region_txt             gname
# Australasia & Oceania  Anarchists                                    1
#                        Animal Liberation Front (ALF)                 2
#                        Anti-Government extremists                    2
#                        Anti-Iran Government Exiles                   1
#                        Anti-Nuclear extremists                       4
#                                                                     ..
# Western Europe         Yellow Organization of Air Force Officers     3
#                        Young Brigade of Navarro                      1
#                        Youth Action Group                            6
#                        Youths                                       11
#                        Zero Tolerance                                5
# Name: region_txt, Length: 4116, dtype: int64

# %%
gang_name.columns
a=gang_name.iloc[:,:10]
a
# Out:
# gname                        1 May  14 K Triad  14 March Coalition  \
# region_txt
# Australasia & Oceania          0.0         0.0                 0.0
# Central America & Caribbean    0.0         0.0                 0.0
# Central Asia                   0.0         0.0                 0.0
# East Asia                      0.0         4.0                 0.0
# Eastern Europe                 0.0         0.0                 0.0
# Middle East & North Africa     0.0         0.0                 1.0
# North America                  0.0         0.0                 0.0
# South America                  0.0         0.0                 0.0
# South Asia                     0.0         0.0                 0.0
# Southeast Asia                 0.0         0.0                 0.0
# Sub-Saharan Africa             0.0         0.0                 0.0
# Western Europe                10.0         0.0                 0.0
#
# gname                        14th of December Command  \
# region_txt
# Australasia & Oceania                             0.0
# Central America & Caribbean                       0.0
# Central Asia                                      0.0
# East Asia                                         0.0
# Eastern Europe                                    0.0
# Middle East & North Africa                        0.0
# North America                                     0.0
# South America                                     3.0
# South Asia                                        0.0
# Southeast Asia                                    0.0
# Sub-Saharan Africa                                0.0
# Western Europe                                    0.0
#
# gname                        15th of September Liberation Legion  \
# region_txt
# Australasia & Oceania                                        0.0
# Central America & Caribbean                                  1.0
# Central Asia                                                 0.0
# East Asia                                                    0.0
# Eastern Europe                                               0.0
# Middle East & North Africa                                   0.0
# North America                                                0.0
# South America                                                0.0
# South Asia                                                   0.0
# Southeast Asia                                               0.0
# Sub-Saharan Africa                                           0.0
# Western Europe                                               0.0
#
# gname                        16 January Organization for the Liberation of Tripoli  \
# region_txt
# Australasia & Oceania                                                      0.0
# Central America & Caribbean                                                0.0
# Central Asia                                                               0.0
# East Asia                                                                  0.0
# Eastern Europe                                                             0.0
# Middle East & North Africa                                                24.0
# North America                                                              0.0
# South America                                                              0.0
# South Asia                                                                 0.0
# Southeast Asia                                                             0.0
# Sub-Saharan Africa                                                         0.0
# Western Europe                                                             0.0
#
# gname                        1920 Revolution Brigades  \
# region_txt
# Australasia & Oceania                             0.0
# Central America & Caribbean                       0.0
# Central Asia                                      0.0
# East Asia                                         0.0
# Eastern Europe                                    0.0
# Middle East & North Africa                        2.0
# North America                                     0.0
# South America                                     0.0
# South Asia                                        0.0
# Southeast Asia                                    0.0
# Sub-Saharan Africa                                0.0
# Western Europe                                    0.0
#
# gname                        19th of July Christian Resistance Brigade  \
# region_txt
# Australasia & Oceania                                              0.0
# Central America & Caribbean                                        1.0
# Central Asia                                                       0.0
# East Asia                                                          0.0
# Eastern Europe                                                     0.0
# Middle East & North Africa                                         0.0
# North America                                                      0.0
# South America                                                      0.0
# South Asia                                                         0.0
# Southeast Asia                                                     0.0
# Sub-Saharan Africa                                                 0.0
# Western Europe                                                     0.0
#
# gname                        1st of May Group  2 April Group
# region_txt
# Australasia & Oceania                     0.0            0.0
# Central America & Caribbean               0.0            0.0
# Central Asia                              0.0            0.0
# East Asia                                 0.0            0.0
# Eastern Europe                            0.0            0.0
# Middle East & North Africa                0.0            0.0
# North America                             0.0            0.0
# South America                             0.0            3.0
# South Asia                                0.0            0.0
# Southeast Asia                            0.0            0.0
# Sub-Saharan Africa                        0.0            0.0
# Western Europe                            4.0            3.0

# %%
a.plot()
plt.title('Gangs Involved region wise')
plt.ylabel('total numbers')
#plt.xlabel('region')
plt.rcParams['figure.figsize'] = (40, 10)

# %% [markdown]
# # **14.Number attacks happen in india each year**

# %%
df_India= attack[attack['country_txt']=='India']
df_number_of_attacks_by_years =df_India['iyear'].value_counts().rename_axis('iyear').reset_index(name='number_of_attacks')
df_number_of_attacks_by_years.head()
# Out:
#    iyear  number_of_attacks
# 0   2016               1025
# 1   2017                966
# 2   2015                884
# 3   2014                860
# 4   2013                694

# %%
plt.rcParams['figure.figsize']=(20,10)
df_number_of_attacks_by_years.sort_values('iyear',ascending= True).plot(kind='bar',x='iyear',y='number_of_attacks')
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
#plt.xlabel('Year', fontsize=20)
#plt.ylabel('Number_of-Attacks', fontsize=20)
plt.title('Number of Attacks Each Year in India', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Number of Attacks Each Year in India')

# %% [markdown]
# # **14.How many number of people killed,wound,kidhost in diffrent region?.**

# %%
kill=attack[["region_txt","nkill","nwound","nhostkid"]].groupby("region_txt").sum()
kill
# Out:
#                                 nkill    nwound  nhostkid
# region_txt
# Australasia & Oceania           150.0     260.0     193.0
# Central America & Caribbean   28708.0    8991.0   16566.0
# Central Asia                   1000.0    2009.0      33.0
# East Asia                      1152.0    9213.0     623.0
# Eastern Europe                 7415.0   12045.0    5999.0
# Middle East & North Africa   137642.0  214308.0   27755.0
# North America                  4916.0   21531.0    -878.0
# South America                 28849.0   16704.0  -14781.0
# South Asia                   101319.0  141360.0   19959.0
# Southeast Asia                15637.0   26259.0    4044.0
# Sub-Saharan Africa            78386.0   52857.0    2650.0
# Western Europe                 6694.0   18332.0    -638.0

# %%
kill.plot()
plt.rcParams['figure.figsize'] = (50, 20)
plt.title('region wise number of people killed')
#plt.xlabel("region text")
plt.ylabel('Numbe of people killed,wound,kidhost')
plt.show()

# %% [markdown]
# # **15.Total humans affected by terrorist attacks from 1970 to 2017?**

# %%
attack["casualty"]=attack["nkill"]+attack["nwound"]
attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iyear             181691 non-null  int64
#  1   country_txt       181691 non-null  object
#  2   region_txt        181691 non-null  object
#  3   city              181691 non-null  object
#  4   success           181691 non-null  int64
#  5   claimed           181691 non-null  float64
#  6   suicide           181691 non-null  int64
#  7   attacktype1_txt   181691 non-null  object
#  8   targtype1_txt     181691 non-null  object
#  9   extended          181691 non-null  int64
#  10  targsubtype1_txt  181691 non-null  object
#  11  gname             181691 non-null  object
#  12  motive            181691 non-null  object
#  13  weaptype1_txt     181691 non-null  object
#  14  nkill             181691 non-null  float64
#  15  nwound            181691 non-null  float64
#  16  property          181691 non-null  int64
#  17  nhostkid          181691 non-null  float64
#  18  vicinity          181691 non-null  int64
#  19  weapsubtype1_txt  181691 non-null  object
#  20  casualty          181691 non-null  float64
# dtypes: float64(5), int64(6), object(10)
# memory usage: 29.1+ MB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
Casualty=attack.loc[:,"casualty"].sum()
print(f"Total number of casualties due to terrorist attack across the world is {Casualty}")
casualty_count=attack[["iyear","casualty"]].groupby("iyear").sum()
casualty_count.head()
# Out:
# Total number of casualties due to terrorist attack across the world is 935737.0
#        casualty
# iyear
# 1970      386.0
# 1971      255.0
# 1972      975.0
# 1973      865.0
# 1974     1404.0

# %%
# sns.lineplot(x = "iyear", y = "casualty", data = attack)
# plt.xticks(rotation = 25)
casualty_count.plot(kind="barh", fontsize=10)

# %%
killed=attack.loc[:,"nkill"].sum()
print(f"Total number of kills due to terrorist attack across the world is {killed}")
kill_count=attack[["iyear","nkill"]].groupby("iyear").sum()
kill_count.head()
# Out:
# Total number of kills due to terrorist attack across the world is 411868.0
#        nkill
# iyear
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %%
kill_count.plot(kind="barh", fontsize=10,color='red')

# %%
wound=attack.loc[:,"nwound"].sum()
print(f"Total number of wounds due to terrorist attack across the world is {wound}")
wound_count=attack[["iyear","nwound"]].groupby("iyear").sum()
wound_count.head()
# Out:
# Total number of wounds due to terrorist attack across the world is 523869.0
#        nwound
# iyear
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %%
wound_count.plot(kind="barh", fontsize=10,color='green')

# %%
attack.describe()
# Out:
#                iyear        success        claimed        suicide  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean     2002.638997       0.889598       0.031592       0.036507
# std        13.259430       0.313391       0.872204       0.187549
# min      1970.000000       0.000000      -9.000000       0.000000
# 25%      1991.000000       1.000000       0.000000       0.000000
# 50%      2009.000000       1.000000       0.000000       0.000000
# 75%      2014.000000       1.000000       0.000000       0.000000
# max      2017.000000       1.000000       1.000000       1.000000
#
#             extended          nkill         nwound       property  \
# count  181691.000000  181691.000000  181691.000000  181691.000000
# mean        0.045346       2.266860       2.883296      -0.544556
# std         0.208063      11.227057      34.309747       3.122889
# min         0.000000       0.000000       0.000000      -9.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       1.000000
# 75%         0.000000       2.000000       2.000000       1.000000
# max         1.000000    1570.000000    8191.000000       1.000000
#
#             nhostkid       vicinity
# count  181691.000000  181691.000000
# mean        0.338624       0.068297
# std        55.306010       0.284553
# min       -99.000000      -9.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         0.000000       0.000000
# max     17000.000000       1.000000

# %% [markdown]
# # We conclude the report with an indepth review of the data given to us via a descriptive analysis of key variables of interests.The analysis is intended to give different insights about terrorists attacks happens in different regions.
